# %% [markdown]
# <a href="https://colab.research.google.com/github/Michael0605/CHALLEGE-DATA-SCIENCE-PYTHON/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()

# Carga con verificación
try:
    tienda = pd.read_csv(url)
    tienda2 = pd.read_csv(url2)
    tienda3 = pd.read_csv(url3)
    tienda4 = pd.read_csv(url4)

    print("✅ Datos cargados correctamente")
    print("\n📊 Resumen de registros por tienda:")
    print(f"- Tienda 1: {len(tienda):,} registros")
    print(f"- Tienda 2: {len(tienda2):,} registros")
    print(f"- Tienda 3: {len(tienda3):,} registros")
    print(f"- Tienda 4: {len(tienda4):,} registros")

    # Verificación adicional de columnas (opcional pero recomendado)
    print("\n🔍 Columnas en Tienda 1:", tienda.columns.tolist())

except Exception as e:
    print(f"❌ Error al cargar datos: {e}")
# Out:
# ✅ Datos cargados correctamente
#
# 📊 Resumen de registros por tienda:
# - Tienda 1: 2,359 registros
# - Tienda 2: 2,359 registros
# - Tienda 3: 2,359 registros
# - Tienda 4: 2,358 registros
#
# 🔍 Columnas en Tienda 1: ['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío', 'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación', 'Método de pago', 'Cantidad de cuotas', 'lat', 'lon']

# %% [markdown]
# #1. Análisis de facturación

# %%
# Calculo de Ingresos por cada tienda
ingreso_tienda1 = tienda['Precio'].sum()
ingreso_tienda2 = tienda2['Precio'].sum()
ingreso_tienda3 = tienda3['Precio'].sum()
ingreso_tienda4 = tienda4['Precio'].sum()

#Calculo de Gastos de envios
envios_tienda1 = tienda['Costo de envío'].sum()
envios_tienda2 = tienda2['Costo de envío'].sum()
envios_tienda3 = tienda3['Costo de envío'].sum()
envios_tienda4 = tienda4['Costo de envío'].sum()

#Calculo de Balance
balance_tienda1 = ingreso_tienda1 - envios_tienda1
balance_tienda2 = ingreso_tienda2 - envios_tienda2
balance_tienda3 = ingreso_tienda3 - envios_tienda3
balance_tienda4 = ingreso_tienda4 - envios_tienda4

#Prueba de datos gestionados
print(ingreso_tienda1)
print(envios_tienda1)
print(balance_tienda1)
# Out:
# 1150880400.0
# 61377900.0
# 1089502500.0

# %%
#Creacion de diccionario de Ingresos por tienda
ingresos = {
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Ingresos Total': [ingreso_tienda1, ingreso_tienda2, ingreso_tienda3, ingreso_tienda4]
}

#Creacion de diccionario de Gastos envios por tienda
costos = {
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Costos Total': [envios_tienda1, envios_tienda2, envios_tienda3, envios_tienda4]
}

#Creacion de diccionario de Balance por tienda PENDIENTE

# %%
# Creacion de Diccionario ingresos_df en un DataFrame
ingresos_df = pd.DataFrame(ingresos)
ingresos_df['Ingresos Total'] = ingresos_df['Ingresos Total'].round(2)

# Creacion de Diccionario costos_df en un DataFrame
costos_df = pd.DataFrame(costos)
costos_df['Costos Total'] = costos_df['Costos Total'].round(2)

# Creacion de Diccionario balance_df en un DataFrame PENDIENTE

# Configuración permanente (para todo el notebook)
pd.set_option('display.float_format', '{:,.2f}'.format)
print(ingresos_df)
print(costos_df)
# Out:
#      Tienda   Ingresos Total
# 0  Tienda 1 1,150,880,400.00
# 1  Tienda 2 1,116,343,500.00
# 2  Tienda 3 1,098,019,600.00
# 3  Tienda 4 1,038,375,700.00
#      Tienda  Costos Total
# 0  Tienda 1 61,377,900.00
# 1  Tienda 2 59,485,100.00
# 2  Tienda 3 58,516,600.00
# 3  Tienda 4 55,317,400.00

# %%
print("\n💻 Resultado:")

# Resultado Ingresos totales por tienda
df_formateado1 = ingresos_df.copy()
df_formateado1['Ingresos Total'] = df_formateado1['Ingresos Total'].map('{:,.2f}'.format)
print(df_formateado1.to_markdown(tablefmt="grid", stralign='right', numalign='right'))

# Resultado Costos totales por tienda
df_formateado2 = costos_df.copy()
df_formateado2['Costos Total'] = df_formateado2['Costos Total'].map('{:,.2f}'.format)
print(df_formateado2.to_markdown(tablefmt="grid", stralign='right', numalign='right'))

# Resultado Costos totales por tienda PENDIENTE
# Out:
# 💻 Resultado:
# +----+----------+------------------+
# |    |   Tienda |   Ingresos Total |
# +====+==========+==================+
# |  0 | Tienda 1 | 1,150,880,400.00 |
# +----+----------+------------------+
# |  1 | Tienda 2 | 1,116,343,500.00 |
# +----+----------+------------------+
# |  2 | Tienda 3 | 1,098,019,600.00 |
# +----+----------+------------------+
# |  3 | Tienda 4 | 1,038,375,700.00 |
# +----+----------+------------------+
# +----+----------+----------------+
# |    |   Tienda |   Costos Total |
# +====+==========+================+
# |  0 | Tienda 1 |  61,377,900.00 |
# +----+----------+----------------+
# |  1 | Tienda 2 |  59,485,100.00 |
# +----+----------+----------------+
# |  2 | Tienda 3 |  58,516,600.00 |
# +----+----------+----------------+
# |  3 | Tienda 4 |  55,317,400.00 |
# +----+----------+----------------+

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# En este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %% [markdown]
# En donde este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
import pandas as pd

## 1. Función para contar productos por categoría en una tienda
def productos_por_categoria(df_tienda, nombre_tienda):
    """
    Calcula la cantidad de productos vendidos por categoría en una tienda

    Args:
        df_tienda (DataFrame): DataFrame de la tienda
        nombre_tienda (str): Nombre de la tienda

    Returns:
        DataFrame: Conteo de productos por categoría
    """
    conteo = df_tienda['Categoría del Producto'].value_counts().reset_index()
    conteo.columns = ['Categoría', 'Cantidad Vendida']
    conteo['Tienda'] = nombre_tienda
    return conteo

# %%
## 2. Procesamiento para todas las tiendas
# Lista para almacenar los resultados
resultados_categorias = []

# Procesamos cada tienda
resultados_categorias.append(productos_por_categoria(tienda,'Tienda 1'))
resultados_categorias.append(productos_por_categoria(tienda2, 'Tienda 2'))
resultados_categorias.append(productos_por_categoria(tienda3, 'Tienda 3'))
resultados_categorias.append(productos_por_categoria(tienda4, 'Tienda 4'))

# Combinamos todos los resultados
categorias_tiendas = pd.concat(resultados_categorias, ignore_index=True)

# %%
## 3. Visualización de resultados
print("\n📊 PRODUCTOS VENDIDOS POR CATEGORÍA EN CADA TIENDA")

# Configuración de visualización
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', '{:,.0f}'.format)

# Mostramos los datos ordenados
for tienda_nombre in ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']:
    print(f"\n🔹 {tienda_nombre}:")
    df_tienda = categorias_tiendas[categorias_tiendas['Tienda'] == tienda_nombre]\
## 3. Visualización de resultados
print("\n📊 PRODUCTOS VENDIDOS POR CATEGORÍA EN CADA TIENDA")

# Configuración de visualización
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', '{:,.0f}'.format)

# Mostramos los datos ordenados
for tienda_nombre in ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']:
    print(f"\n🔹 {tienda_nombre}:")
    df_tienda = categorias_tiendas[categorias_tiendas['Tienda'] == tienda_nombre]\
                .sort_values('Cantidad Vendida', ascending=False)\
                .reset_index(drop=True)
    print(df_tienda.to_markdown(tablefmt="grid", stralign='right', numalign='right'))
# Out:
# 📊 PRODUCTOS VENDIDOS POR CATEGORÍA EN CADA TIENDA
#
# 🔹 Tienda 1:
#
# 🔹 Tienda 2:
#
# 🔹 Tienda 3:
#
# 🔹 Tienda 4:
#
# 📊 PRODUCTOS VENDIDOS POR CATEGORÍA EN CADA TIENDA
#
# 🔹 Tienda 1:
# +----+-------------------------+--------------------+----------+
# |    |               Categoría |   Cantidad Vendida |   Tienda |
# +====+=========================+====================+==========+
# |  0 |                 Muebles |                465 | Tienda 1 |
# +----+-------------------------+--------------------+----------+
# |  1 |            Electrónicos |                448 | Tienda 1 |
# +----+-------------------------+--------------------+----------+
# |  2 |                Juguetes |                324 | Tienda 1 |
# +----+-------------------------+--------------------+----------+
# |  3 |       Electrodomésticos |                312 | Tienda 1 |
# +----+-------------------------+--------------------+----------+
# |  4 |    Deportes y diversión |                284 | Tienda 1 |
# ...

# %%
import matplotlib.pyplot as plt

# Gráfico para una tienda específica
tienda1_cat = categorias_tiendas[categorias_tiendas['Tienda'] == 'Tienda 1']
plt.figure(figsize=(10, 5))
plt.bar(tienda1_cat['Categoría'], tienda1_cat['Cantidad Vendida'])
plt.title('Ventas por categoría - Tienda 1')
plt.xticks(rotation=45)
plt.ylabel('Cantidad vendida')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración de estilo CORREGIDA (usando seaborn directamente)
sns.set_theme(style="whitegrid")  # Estilo moderno de seaborn
plt.rcParams['figure.facecolor'] = 'white'  # Fondo blanco para los gráficos

# 1. Función para analizar categorías (mejorada)
def analizar_categorias(df, nombre_tienda, top_n=5):
    categorias = (
        df['Categoría del Producto']
        .value_counts()
        .nlargest(top_n)
        .reset_index()
    )
    categorias.columns = ['Categoría', 'Cantidad']
    categorias['Tienda'] = nombre_tienda
    categorias['Porcentaje'] = (categorias['Cantidad'] / categorias['Cantidad'].sum()) * 100
    return categorias

# 2. Procesamiento para todas las tiendas (con manejo de errores)
try:
    top_categorias = pd.concat([
        analizar_categorias(tienda, 'Tienda 1'),
        analizar_categorias(tienda2, 'Tienda 2'),
        analizar_categorias(tienda3, 'Tienda 3'),
        analizar_categorias(tienda4, 'Tienda 4')
    ])

    # 3. Visualización mejorada
    g = sns.FacetGrid(top_categorias, col='Tienda', col_wrap=2, height=5, aspect=1.5)
    g.map_dataframe(
        sns.barplot,
        x='Cantidad',
        y='Categoría',
        palette='Blues_d'
    )

    # Añadir títulos y etiquetas
    g.set_titles("{col_name}")
    g.set_axis_labels("Unidades Vendidas", "")

    # Añadir valores en las barras
    for ax in g.axes.flat:
        for p in ax.patches:
            ax.annotate(
                f"{int(p.get_width()):,}\n({p.get_width()/top_categorias[top_categorias['Tienda']==ax.title.get_text()]['Cantidad'].sum():.1f}%)",
                (p.get_width(), p.get_y() + p.get_height()/2),
                ha='left', va='center', xytext=(5, 0), textcoords='offset points'
            )

    plt.suptitle('Top Categorías por Tienda', y=1.02, fontweight='bold')
    plt.tight_layout()
    plt.show()

    # 4. Tabla resumen interactiva
    print("\n📊 Tabla Resumen de Categorías Principales")
    display(
        top_categorias.pivot_table(
            index='Categoría',
            columns='Tienda',
            values='Cantidad',
            aggfunc='sum',
            fill_value=0
        )
        .style
        .background_gradient(cmap='Blues', axis=1)
        .format('{:,.0f}')
        .set_caption('Unidades Vendidas por Categoría y Tienda')
    )

except Exception as e:
    print(f"❌ Error en el análisis: {e}")
    print("Verifica que los DataFrames (tienda, tienda2, etc.) estén correctamente cargados")
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración de estilos
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))

## 1. Cálculo de calificaciones promedio por tienda
def calcular_satisfaccion():
    # Diccionario para almacenar resultados
    resultados = {
        'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
        'Calificación Promedio': [
            tienda['Calificación'].mean(),
            tienda2['Calificación'].mean(),
            tienda3['Calificación'].mean(),
            tienda4['Calificación'].mean()
        ],
        'Mediana de Calificación': [
            tienda['Calificación'].median(),
            tienda2['Calificación'].median(),
            tienda3['Calificación'].median(),
            tienda4['Calificación'].median()
        ],
        'Total Reseñas': [
            len(tienda),
            len(tienda2),
            len(tienda3),
            len(tienda4)
        ]
    }

    return pd.DataFrame(resultados)

# Calculamos las métricas
satisfaccion_df = calcular_satisfaccion().round(2)

## 2. Visualización de resultados
# Gráfico de barras para calificaciones promedio
plt.figure(figsize=(12, 6))
ax = sns.barplot(
    data=satisfaccion_df,
    x='Tienda',
    y='Calificación Promedio',
    palette='viridis',
    errorbar=None
)

# Añadir etiquetas de valor
for p in ax.patches:
    ax.annotate(
        f"{p.get_height():.2f}",
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center', va='center',
        xytext=(0, 10),
        textcoords='offset points'
    )

plt.title('Calificación Promedio por Tienda', fontweight='bold', pad=20)
plt.xlabel('Tienda', labelpad=10)
plt.ylabel('Puntuación Promedio (1-5)', labelpad=10)
plt.ylim(0, 5.5)  # La escala de calificación es de 1 a 5
plt.tight_layout()
plt.show()

## 3. Análisis detallado
print("\n🔍 Análisis Detallado de Satisfacción:")
display(satisfaccion_df.style
       .background_gradient(subset=['Calificación Promedio'], cmap='RdYlGn', vmin=1, vmax=5)
       .format({'Calificación Promedio': '{:.2f}', 'Mediana de Calificación': '{:.2f}'})
       .set_caption('Métricas de Satisfacción del Cliente'))

## 4. Distribución de calificaciones (boxplot)
plt.figure(figsize=(12, 6))
sns.boxplot(
    data=pd.concat([
        tienda.assign(Tienda='Tienda 1'),
        tienda2.assign(Tienda='Tienda 2'),
        tienda3.assign(Tienda='Tienda 3'),
        tienda4.assign(Tienda='Tienda 4')
    ]),
    x='Tienda',
    y='Calificación',
    palette='Set2'
)
plt.title('Distribución de Calificaciones por Tienda', fontweight='bold', pad=20)
plt.xlabel('Tienda', labelpad=10)
plt.ylabel('Calificación', labelpad=10)
plt.ylim(0, 5.5)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-23-23930e01e49e>:42: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(
# 🔍 Análisis Detallado de Satisfacción:
# <style type="text/css">
# #T_21ee9_row0_col1 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_21ee9_row1_col1 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_21ee9_row2_col1 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_21ee9_row3_col1 {
#   background-color: #84ca66;
#   color: #000000;
# }
# </style>
# <table id="T_21ee9" class="dataframe">
#   <caption>Métricas de Satisfacción del Cliente</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21ee9_level0_col0" class="col_heading level0 col0" >Tienda</th>
#       <th id="T_21ee9_level0_col1" class="col_heading level0 col1" >Calificación Promedio</th>
# ...

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FuncFormatter

# Configuración de estilos
sns.set_theme(style="whitegrid")
plt.rcParams['figure.facecolor'] = 'white'

# Función para formatear números grandes
def format_thousands(x, pos):
    return f'{int(x/1000)}K' if x >= 1000 else f'{int(x)}'

thousands_formatter = FuncFormatter(format_thousands)

## 1. Función para analizar productos por tienda
def analizar_productos(df, nombre_tienda, top_n=5):
    # Productos más vendidos
    top_productos = df['Producto'].value_counts().nlargest(top_n).reset_index()
    top_productos.columns = ['Producto', 'Ventas']
    top_productos['Tipo'] = 'Más vendidos'
    top_productos['Tienda'] = nombre_tienda

    # Productos menos vendidos
    bottom_productos = df['Producto'].value_counts().nsmallest(top_n).reset_index()
    bottom_productos.columns = ['Producto', 'Ventas']
    bottom_productos['Tipo'] = 'Menos vendidos'
    bottom_productos['Tienda'] = nombre_tienda

    return pd.concat([top_productos, bottom_productos])

## 2. Procesamiento para todas las tiendas
productos_tiendas = pd.concat([
    analizar_productos(tienda, 'Tienda 1'),
    analizar_productos(tienda2, 'Tienda 2'),
    analizar_productos(tienda3, 'Tienda 3'),
    analizar_productos(tienda4, 'Tienda 4')
])

## 3. Visualización de productos más vendidos
plt.figure(figsize=(14, 10))
g = sns.FacetGrid(productos_tiendas[productos_tiendas['Tipo'] == 'Más vendidos'],
                 col='Tienda', col_wrap=2, height=5, aspect=1.5)
g.map_dataframe(sns.barplot, x='Ventas', y='Producto', palette='Blues_d')
g.set_titles("{col_name}")
g.set_axis_labels("Unidades Vendidas", "")
g.fig.suptitle('Top 5 Productos Más Vendidos por Tienda', y=1.05, fontweight='bold')

# Añadir etiquetas de valor
for ax in g.axes.flat:
    ax.xaxis.set_major_formatter(thousands_formatter)
    for p in ax.patches:
        ax.annotate(format_thousands(p.get_width(), None),
                   (p.get_width(), p.get_y() + p.get_height()/2),
                   ha='left', va='center', xytext=(5, 0), textcoords='offset points')

plt.tight_layout()
plt.show()

## 4. Visualización de productos menos vendidos
plt.figure(figsize=(14, 10))
g = sns.FacetGrid(productos_tiendas[productos_tiendas['Tipo'] == 'Menos vendidos'],
                 col='Tienda', col_wrap=2, height=5, aspect=1.5)
g.map_dataframe(sns.barplot, x='Ventas', y='Producto', palette='Reds_d')
g.set_titles("{col_name}")
g.set_axis_labels("Unidades Vendidas", "")
g.fig.suptitle('Top 5 Productos Menos Vendidos por Tienda', y=1.05, fontweight='bold')

# Añadir etiquetas de valor
for ax in g.axes.flat:
    ax.xaxis.set_major_formatter(thousands_formatter)
    for p in ax.patches:
        ax.annotate(format_thousands(p.get_width(), None),
                   (p.get_width(), p.get_y() + p.get_height()/2),
                   ha='left', va='center', xytext=(5, 0), textcoords='offset points')

plt.tight_layout()
plt.show()

## 5. Tabla resumen comparativa
print("\n📊 Tabla Comparativa de Productos Destacados")

# Crear resumen comparativo
resumen_productos = productos_tiendas.pivot_table(
    index=['Tienda', 'Tipo'],
    columns='Producto',
    values='Ventas',
    aggfunc='sum'
).fillna(0)

display(resumen_productos.style
       .background_gradient(cmap='Blues', axis=1)
       .format('{:,.0f}')
       .set_caption('Resumen de Ventas por Producto y Tienda'))

## 6. Análisis de categorías de productos menos vendidos
print("\n🔍 Análisis de Categorías de Productos Menos Vendidos")
productos_menos_vendidos = productos_tiendas[productos_tiendas['Tipo'] == 'Menos vendidos']

# Obtener categorías para estos productos
def obtener_categorias(df, productos):
    return df[df['Producto'].isin(productos)][['Producto', 'Categoría del Producto']].drop_duplicates()

categorias_menos_vendidas = pd.concat([
    obtener_categorias(tienda, productos_menos_vendidos[productos_menos_vendidos['Tienda'] == 'Tienda 1']['Producto']),
    obtener_categorias(tienda2, productos_menos_vendidos[productos_menos_vendidos['Tienda'] == 'Tienda 2']['Producto']),
    obtener_categorias(tienda3, productos_menos_vendidos[productos_menos_vendidos['Tienda'] == 'Tienda 3']['Producto']),
    obtener_categorias(tienda4, productos_menos_vendidos[productos_menos_vendidos['Tienda'] == 'Tienda 4']['Producto'])
])
def obtener_categorias_con_tienda(df, productos, nombre_tienda):
    return (
        df[df['Producto'].isin(productos)]
        [['Producto', 'Categoría del Producto']]
        .drop_duplicates()
        .assign(Tienda=nombre_tienda)  # Añadimos la columna Tienda
    )

# Obtenemos categorías con información de tienda
categorias_menos_vendidas = pd.concat([
    obtener_categorias_con_tienda(tienda,
                                productos_menos_vendidos[productos_menos_vendidos['Tienda'] == 'Tienda 1']['Producto'],
                                'Tienda 1'),
    obtener_categorias_con_tienda(tienda2,
                                productos_menos_vendidos[productos_menos_vendidos['Tienda'] == 'Tienda 2']['Producto'],
                                'Tienda 2'),
    obtener_categorias_con_tienda(tienda3,
                                productos_menos_vendidos[productos_menos_vendidos['Tienda'] == 'Tienda 3']['Producto'],
                                'Tienda 3'),
    obtener_categorias_con_tienda(tienda4,
                                productos_menos_vendidos[productos_menos_vendidos['Tienda'] == 'Tienda 4']['Producto'],
                                'Tienda 4')
])

# Merge correcto (ahora ambas tablas tienen 'Producto' y 'Tienda')
resultado_final = categorias_menos_vendidas.merge(
    productos_menos_vendidos[['Producto', 'Tienda', 'Ventas', 'Tipo']],
    on=['Producto', 'Tienda']
).sort_values(['Tienda', 'Ventas'])

# Mostramos resultados
display(resultado_final.style.set_caption('Productos menos vendidos con sus categorías'))
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FuncFormatter

# Configuración de estilos
sns.set_theme(style="whitegrid")
plt.rcParams['figure.facecolor'] = 'white'

## 1. Cálculo de métricas de envío por tienda
def calcular_costos_envio():
    # Diccionario para almacenar resultados
    resultados = {
        'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
        'Costo Promedio Envío': [
            tienda['Costo de envío'].mean(),
            tienda2['Costo de envío'].mean(),
            tienda3['Costo de envío'].mean(),
            tienda4['Costo de envío'].mean()
        ],
        'Costo Total Envío': [
            tienda['Costo de envío'].sum(),
            tienda2['Costo de envío'].sum(),
            tienda3['Costo de envío'].sum(),
            tienda4['Costo de envío'].sum()
        ],
        'Cantidad de Envíos': [
            len(tienda),
            len(tienda2),
            len(tienda3),
            len(tienda4)
        ]
    }

    return pd.DataFrame(resultados)

# Calculamos las métricas
costos_envio_df = calcular_costos_envio()
costos_envio_df['Costo Promedio Envío'] = costos_envio_df['Costo Promedio Envío'].round(2)
costos_envio_df['Costo Total Envío'] = costos_envio_df['Costo Total Envío'].round(2)

## 2. Visualización de costos promedio
plt.figure(figsize=(12, 6))
ax = sns.barplot(
    data=costos_envio_df,
    x='Tienda',
    y='Costo Promedio Envío',
    palette='coolwarm',
    errorbar=None
)

# Añadir etiquetas de valor
for p in ax.patches:
    ax.annotate(
        f"${p.get_height():,.2f}",
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center', va='center',
        xytext=(0, 10),
        textcoords='offset points',
        fontweight='bold'
    )

plt.title('Costo Promedio de Envío por Tienda', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Tienda', labelpad=10, fontweight='bold')
plt.ylabel('Costo Promedio (USD)', labelpad=10, fontweight='bold')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
sns.despine()
plt.tight_layout()
plt.show()

## 3. Análisis comparativo
plt.figure(figsize=(14, 7))
# Gráfico combinado de barras (total) y línea (promedio)
ax1 = sns.barplot(
    data=costos_envio_df,
    x='Tienda',
    y='Costo Total Envío',
    color='skyblue',
    label='Costo Total'
)

ax2 = ax1.twinx()
sns.lineplot(
    data=costos_envio_df,
    x='Tienda',
    y='Costo Promedio Envío',
    color='crimson',
    marker='o',
    markersize=10,
    linewidth=3,
    ax=ax2,
    label='Costo Promedio'
)

# Añadir etiquetas y leyenda
ax1.set_ylabel('Costo Total Envío (USD)', fontweight='bold')
ax2.set_ylabel('Costo Promedio (USD)', fontweight='bold')
ax1.set_xlabel('Tienda', fontweight='bold')
plt.title('Comparación Costos de Envío: Total vs Promedio', fontsize=16, fontweight='bold', pad=20)

# Combinar leyendas
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper right')

# Formatear ejes
ax1.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f"${x:,.0f}"))
ax2.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f"${x:,.2f}"))

plt.tight_layout()
plt.show()

## 4. Tabla resumen detallada
print("\n📊 Resumen Analítico de Costos de Envío")
display(costos_envio_df.style
       .format({
           'Costo Promedio Envío': '${:,.2f}',
           'Costo Total Envío': '${:,.2f}',
           'Cantidad de Envíos': '{:,}'
       })
       .background_gradient(subset=['Costo Promedio Envío'], cmap='YlOrRd')
       .background_gradient(subset=['Costo Total Envío'], cmap='Blues')
       .set_caption('Métricas de Costos de Envío por Tienda'))

## 5. Análisis de distribución (boxplot)
plt.figure(figsize=(12, 6))
sns.boxplot(
    data=pd.concat([
        tienda.assign(Tienda='Tienda 1'),
        tienda2.assign(Tienda='Tienda 2'),
        tienda3.assign(Tienda='Tienda 3'),
        tienda4.assign(Tienda='Tienda 4')
    ]),
    x='Tienda',
    y='Costo de envío',
    palette='Set2'
)
plt.title('Distribución de Costos de Envío por Tienda', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Tienda', labelpad=10, fontweight='bold')
plt.ylabel('Costo de envío (USD)', labelpad=10, fontweight='bold')
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f"${x:,.0f}"))
sns.despine()
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-26-a5c05c0216d2>:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(
# 📊 Resumen Analítico de Costos de Envío
# <style type="text/css">
# #T_e0dfd_row0_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_e0dfd_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e0dfd_row1_col1 {
#   background-color: #f03523;
#   color: #f1f1f1;
# }
# #T_e0dfd_row1_col2 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_e0dfd_row2_col1 {
#   background-color: #fd8038;
#   color: #f1f1f1;
# }
# #T_e0dfd_row2_col2 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_e0dfd_row3_col1 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_e0dfd_row3_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_e0dfd" class="dataframe">
# ...

# %%
# Creación de un dashboard con subplots
fig = plt.figure(figsize=(18, 12))
gs = fig.add_gridspec(2, 2)

# Gráfico 1: Ingresos por tienda
ax1 = fig.add_subplot(gs[0, 0])
ingresos_tiendas = [tienda['Precio'].sum(), tienda2['Precio'].sum(),
                    tienda3['Precio'].sum(), tienda4['Precio'].sum()]
sns.barplot(x=['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
            y=ingresos_tiendas, palette='rocket', ax=ax1)
ax1.set_title('Ingresos Totales por Tienda', fontweight='bold')
ax1.set_ylabel('Ingresos (USD)')
ax1.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f"${x/1e6:,.1f}M"))

# Gráfico 2: Costos de envío promedio
ax2 = fig.add_subplot(gs[0, 1])
costos_envio = [tienda['Costo de envío'].mean(), tienda2['Costo de envío'].mean(),
                tienda3['Costo de envío'].mean(), tienda4['Costo de envío'].mean()]
sns.barplot(x=['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
            y=costos_envio, palette='mako', ax=ax2)
ax2.set_title('Costo Promedio de Envío por Tienda', fontweight='bold')
ax2.set_ylabel('Costo (USD)')
ax2.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f"${x:,.0f}"))

# Gráfico 3: Calificaciones promedio
ax3 = fig.add_subplot(gs[1, 0])
calificaciones = [tienda['Calificación'].mean(), tienda2['Calificación'].mean(),
                  tienda3['Calificación'].mean(), tienda4['Calificación'].mean()]
sns.barplot(x=['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
            y=calificaciones, palette='flare', ax=ax3)
ax3.set_title('Calificación Promedio por Tienda', fontweight='bold')
ax3.set_ylabel('Puntuación (1-5)')
ax3.set_ylim(0, 5)

# Gráfico 4: Método de pago más popular
ax4 = fig.add_subplot(gs[1, 1])
metodo_popular = pd.concat([tienda, tienda2, tienda3, tienda4])['Método de pago'].value_counts()
sns.barplot(x=metodo_popular.index, y=metodo_popular.values, palette='crest', ax=ax4)
ax4.set_title('Métodos de Pago Más Utilizados', fontweight='bold')
ax4.set_ylabel('Cantidad de Transacciones')
ax4.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-27-576d498cb08a>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
# <ipython-input-27-576d498cb08a>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
# <ipython-input-27-576d498cb08a>:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
# <ipython-input-27-576d498cb08a>:38: FutureWarning:
#
# ...
